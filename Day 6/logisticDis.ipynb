# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(np.random.logistic(loc=2, scale=10, size=1000), kind='kde')

plt.title('Logistic Distribution')
plt.xlabel('')
plt.ylabel('Probability')
plt.grid(True)
plt.show()
