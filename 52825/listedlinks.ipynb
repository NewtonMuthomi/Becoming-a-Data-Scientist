# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

def traverse_print(head):
    currentNode = head
    while currentNode:
        print(currentNode.data, end='->')
        currentNode = currentNode.next
    print('null')

node1 = Node(23)
node2 = Node(4)
node3 = Node(53)
node4 = Node(78)
node5 = Node(90)

node1.next=node2
node2.next=node3
node3.next=node4
node4.next=node5

traverse_print(node1)
# Out:
# 23->4->53->78->90->null

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

def circular_traverse_print(head):
    currentNode = head
    startingNode = head
    print(currentNode.data, end='->')
    currentNode = currentNode.next
    
    while currentNode != startingNode:
        print(currentNode.data, end='->')
        currentNode = currentNode.next
    print('...')

node1 = Node(23)
node2 = Node(4)
node3 = Node(53)
node4 = Node(78)
node5 = Node(90)

node1.next=node2
node2.next=node3
node3.next=node4
node4.next=node5
node5.next=node1

circular_traverse_print(node1)
# Out:
# 23->4->53->78->90->...

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

def double_traverse(head, tail):
    currentNode = head
    print('Traverse forward:')
    while currentNode:
        print(currentNode.data, end='->')
        currentNode = currentNode.next
    print('null')

    currentNode = tail
    print('\nTraverse backward:')
    while currentNode:
        print(currentNode.data, end='->')
        currentNode = currentNode.prev
    print('null')

node1 = Node(23)
node2 = Node(4)
node3 = Node(53)
node4 = Node(78)
node5 = Node(90)

node1.next = node2

node2.prev = node1
node2.next = node3

node3.prev = node2
node3.next = node4

node4.prev = node3
node4.next = node5

node5.prev = node4

double_traverse(node1, node5)
# Out:
# Traverse forward:
# 23->4->53->78->90->null
#
# Traverse backward:
# 90->78->53->4->23->null

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

def circular_double_traverse(head, tail):
    currentNode = head
    startingNode = head
    print('Traverse Forward:')
    print(currentNode.data, end='->')
    currentNode = currentNode.next

    while currentNode != startingNode:
        print(currentNode.data, end='->')
        currentNode=currentNode.next
    print('...')

    currentNode = tail
    endingNode = tail
    print('\nTraverse Backward:')
    print(currentNode.data, end='->')
    currentNode = currentNode.prev
    
    while currentNode != endingNode:
        print(currentNode.data, end='->')
        currentNode = currentNode.prev
    print('...')

node1 = Node(23)
node2 = Node(4)
node3 = Node(53)
node4 = Node(78)
node5 = Node(90)

node1.next = node2
node1.prev = node5

node2.prev = node1
node2.next = node3

node3.prev = node2
node3.next = node4

node4.prev = node3
node4.next = node5

node5.prev = node4
node5.next = node1

circular_double_traverse(node1, node5)
# Out:
# Traverse Forward:
# 23->4->53->78->90->...
#
# Traverse Backward:
# 90->78->53->4->23->...

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

def lowestValue(head):
    minVal = head.data
    currentNode = head.next

    while currentNode:
        if currentNode.data < minVal:
            minVal = currentNode.data
        currentNode.next
    return minVal

node1 = Node(23)
node2 = Node(4)
node3 = Node(53)
node4 = Node(78)
node5 = Node(90)

node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5

lowestValue(node1)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

def singleTraverse(head):
    currentNode = head
    while currentNode:
        print(currentNode.data, end='->')
        currentNode = currentNode.next
    print('...')

def insertNode(head, newNode, position):
    if position == 1:
        newNode.next = head
        return newNode

    currentNode = head
    for _ in range(position - 2):
        if currentNode is None:
            break
        currentNode = currentNode.next

    newNode.next = currentNode.next
    currentNode.next = newNode
    return head

node1 = Node(7)
node2 = Node(3)
node3 = Node(2)
node4 = Node(9)

node1.next = node2
node2.next = node3
node3.next = node4

print('Original List:')
singleTraverse(node1)

node1 = insertNode(node1, Node(97), 5)
print('\nModified List:')
singleTraverse(node1)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

def traverse_print(head):
    currentNode = head
    while currentNode:
        print(currentNode.data, end='->')
        currentNode = currentNode.next
    print('null')

def deleteSpecificNode(head, nodeToDelete):
    if head == nodeToDelete:
        return head.next

    currentNode = head
    while currentNode and currentNode.next != nodeToDelete:
        currentNode = currentNode.next

    if currentNode.next is None:
        return head

    currentNode.next = currentNode.next.next

    return head

node1 = Node(23)
node2 = Node(4)
node3 = Node(53)
node4 = Node(78)
node5 = Node(90)

node1.next=node2
node2.next=node3
node3.next=node4
node4.next=node5

print('Before deletion:')
traverse_print(node1)

node1 = deleteSpecificNode(node1, node4)

print('\nAfter deletion:')
traverse_print(node1)
# Out:
# Before deletion:
# 23->4->53->78->90->null
#
# After deletion:
# 23->4->53->90->null
